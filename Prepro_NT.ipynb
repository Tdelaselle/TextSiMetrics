# %% [markdown]
# # NT text preprocessing

# %%
import pandas as pd
import numpy as np  
# import matplotlib.pyplot as plt 
import openpyxl
import lxml
import nltk

# %% [markdown]
# ## Load NT file from Proiel

# %%
# Load the XML data
from io import StringIO
from lxml import etree

# Function to clean xml:id attributes
def clean_xml_ids(xml_content):
    # Replace invalid characters in xml:id attributes
    cleaned_content = xml_content.replace('xml:id="RHE_Ps_147_12_c _', 'xml:id="RHE_Ps_147_12_c_')
    return cleaned_content

# Read the XML file content
with open('data/SBLGNT/greek-nt.xml', 'r', encoding='utf-8') as file:
    xml_content = file.read()

# Clean the xml:id attributes
cleaned_xml_content = clean_xml_ids(xml_content)
# display(cleaned_xml_content[0:1000])

# Parse the cleaned XML content
tree = etree.parse('data/SBLGNT/greek-nt.xml')
root = tree.getroot()

# %%
for elem in root.iter():
    if elem.tag == 'sentence':
        print(elem.tag,elem.attrib)
# Out:
# sentence {'id': '14671', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47587', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47588', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47589', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47590', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47591', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47592', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47593', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47594', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47595', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47596', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47597', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47598', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47599', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47600', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47601', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47602', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47603', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47604', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47605', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47606', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47607', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47608', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47609', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47610', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47611', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47612', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47613', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47614', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47615', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47616', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47617', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47618', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47619', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47620', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47621', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47622', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47623', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47624', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47625', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14675', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14676', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14677', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14678', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47626', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47627', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47628', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14680', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47629', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47630', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14682', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14683', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14684', 'status': 'reviewed'}
# sentence {'id': '47631', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47632', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14686', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14687', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47633', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47634', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14689', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14690', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14691', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47635', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47636', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14693', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14694', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14695', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14696', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14697', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47637', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47638', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14699', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14700', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '58378', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14702', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47639', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47640', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14704', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47641', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47642', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14706', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14707', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14708', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14709', 'status': 'reviewed'}
# sentence {'id': '47643', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47644', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47645', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14711', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47646', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47647', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47648', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47649', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47650', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14714', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47651', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47652', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14716', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47653', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47654', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47655', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14718', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14719', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14720', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14721', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14722', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47656', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47657', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14724', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14725', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14726', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47658', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47659', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47660', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14728', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14729', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14730', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47661', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47662', 'status': 'reviewed'}
# sentence {'id': '14732', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14733', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47663', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47664', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47665', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47666', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47667', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47668', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47669', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14737', 'status': 'reviewed'}
# sentence {'id': '58379', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47670', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47671', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47672', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47673', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47674', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14740', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14741', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47675', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47676', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14743', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14744', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14745', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14746', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47677', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47678', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47679', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14748', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14749', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47680', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47681', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14751', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14752', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14753', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14754', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14755', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14756', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14757', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14758', 'status': 'reviewed'}
# sentence {'id': '14759', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14760', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47682', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47683', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14762', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14763', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14764', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14765', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14766', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14767', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14768', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14769', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14770', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14771', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14772', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14773', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14774', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14775', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14776', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14777', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14778', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14779', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14780', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14781', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '57381', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14782', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14783', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14784', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47684', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47685', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14786', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14787', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14788', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14789', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '57379', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14791', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47686', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47687', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47688', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47689', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14794', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14795', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14796', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14797', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14798', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47690', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47691', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14800', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47692', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47693', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '47694', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14802', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '14803', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '
 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '159650', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '159649', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '159648', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '159647', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '159646', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '159645', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '159644', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '33421', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '159655', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '33422', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '33423', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '159656', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '33424', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '159657', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '33425', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '33426', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '33427', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '159658', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '33428', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '33429', 'status': 'reviewed'}
# sentence {'id': '33430', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '159659', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '159660', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '33432', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '33433', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '33434', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '33435', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '159661', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '33436', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '33437', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '33438', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '33439', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '33440', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '159662', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '33441', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '33442', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '33443', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '159665', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '159664', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '33444', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '33445', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '33446', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '33447', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '33448', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '33449', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '33450', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '159666', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '33451', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '159667', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '33452', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '159668', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '33453', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '159669', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '33454', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '33455', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '33456', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '33457', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '159670', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '33458', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '159671', 'status': 'reviewed', 'presentation-after': ' '}
# sentence {'id': '33459', 'status': 'reviewed'}

# %%
# Build dataframe listed by verse, from TEI root

import dis


NT_sentence = pd.DataFrame(columns=['verse_1', 'verse_2', 'token', 'lemma', 'pos'])

token_list = []
lemma_list = []
pos_list = []
v1 = ''
v2 = ''
sentence_id = ''
for elem in root.iter():
    if elem.tag == 'sentence':
        NT_sentence.loc[len(NT_sentence)] = [v1, v2, token_list, lemma_list, pos_list]         
        token_list = []
        lemma_list = []
        pos_list = []
        v1 = ''

    if elem.get('lemma') is not None:
        if v1 == '':
            v1 = elem.get('citation-part')
        lemma_list.append(str(elem.get('lemma')))
        pos_list.append(str(elem.get('part-of-speech')))
        token_list.append(str(elem.get('form')))
    
    if elem.get('citation-part') is not None:
        v2 = elem.get('citation-part')

# Delete first line of NT_sentence
NT_sentence = NT_sentence.drop(NT_sentence.index[0])

display(NT_sentence)
# Out:
#      verse_1   verse_2                                              token  \
# 1   MATT 1.1  MATT 1.1  [Βίβλος, γενέσεως, Ἰησοῦ, Χριστοῦ, υἱοῦ, Δαυεὶ...
# 2   MATT 1.2  MATT 1.2                    [Ἀβραὰμ, ἐγέννησεν, τὸν, Ἰσαάκ]
# 3   MATT 1.2  MATT 1.2                 [Ἰσαὰκ, δὲ, ἐγέννησεν, τὸν, Ἰακώβ]
# 4   MATT 1.2  MATT 1.2  [Ἰακὼβ, δὲ, ἐγέννησεν, τὸν, Ἰούδαν, καὶ, τοὺς,...
# 5   MATT 1.3  MATT 1.3  [Ἰούδας, δὲ, ἐγέννησεν, τὸν, Φάρες, καὶ, τὸν, ...
# 6   MATT 1.3  MATT 1.3                 [Φάρες, δὲ, ἐγέννησεν, τὸν, Ἑσρώμ]
# 7   MATT 1.3  MATT 1.3                  [Ἑσρὼμ, δὲ, ἐγέννησεν, τὸν, Ἀράμ]
# 8   MATT 1.4  MATT 1.4               [Ἀρὰμ, δὲ, ἐγέννησεν, τὸν, Ἀμιναδάβ]
# 9   MATT 1.4  MATT 1.4            [Ἀμιναδὰβ, δὲ, ἐγέννησεν, τὸν, Ναασσών]
# 10  MATT 1.4  MATT 1.4              [Ναασσὼν, δὲ, ἐγέννησεν, τὸν, Σαλμών]
#
#                                                 lemma  \
# 1   [βίβλος, γένεσις, Ἰησοῦς, Χριστός, υἱός, Δαυίδ...
# 2                          [Ἀβραάμ, γεννάω, ὁ, Ἰσαάκ]
# 3                       [Ἰσαάκ, δέ, γεννάω, ὁ, Ἰακώβ]
# 4   [Ἰακώβ, δέ, γεννάω, ὁ, Ἰούδας, καί, ὁ, ἀδελφός...
# 5   [Ἰούδας, δέ, γεννάω, ὁ, Φάρες, καί, ὁ, Ζάρα, ἐ...
# 6                       [Φάρες, δέ, γεννάω, ὁ, Ἑσρώμ]
# 7                        [Ἑσρώμ, δέ, γεννάω, ὁ, Ἀράμ]
# 8                     [Ἀράμ, δέ, γεννάω, ὁ, Ἀμιναδάβ]
# 9                  [Ἀμιναδάβ, δέ, γεννάω, ὁ, Ναασσών]
# 10                   [Ναασσών, δέ, γεννάω, ὁ, Σαλμών]
#
#                                              pos
# 1               [Nb, Nb, Ne, Ne, Nb, Ne, Nb, Ne]
# 2                               [Ne, V-, S-, Ne]
# 3                           [Ne, Df, V-, S-, Ne]
# 4           [Ne, Df, V-, S-, Ne, C-, S-, Nb, Pp]
# 5   [Ne, Df, V-, S-, Ne, C-, S-, Ne, R-, S-, Ne]
# 6                           [Ne, Df, V-, S-, Ne]
# 7                           [Ne, Df, V-, S-, Ne]
# 8                           [Ne, Df, V-, S-, Ne]
# 9                           [Ne, Df, V-, S-, Ne]
# 10                          [Ne, Df, V-, S-, Ne]

# %%
# Build dataframe listed by verse, from TEI root

NT = pd.DataFrame(columns=['verse', 'token', 'lemma', 'pos'])

token_list = []
lemma_list = []
pos_list = []
verse = ''
for elem in root.iter():
    if elem.tag == 'token':
        if elem.get('citation-part') != verse:
            NT.loc[len(NT)] = [verse, token_list, lemma_list, pos_list]         
            token_list = []
            lemma_list = []
            pos_list = []
            verse = elem.get('citation-part')
        if elem.get('lemma') is not None:
            lemma_list.append(str(elem.get('lemma')))
            pos_list.append(str(elem.get('part-of-speech')))
            token_list.append(str(elem.get('form')))

# Delete first line of NT
NT = NT.drop(NT.index[0])

display(NT)
# Out:
#           verse                                              token  \
# 1      MATT 1.1  [Βίβλος, γενέσεως, Ἰησοῦ, Χριστοῦ, υἱοῦ, Δαυεὶ...
# 2      MATT 1.2  [Ἀβραὰμ, ἐγέννησεν, τὸν, Ἰσαάκ, Ἰσαὰκ, δὲ, ἐγέ...
# 3      MATT 1.3  [Ἰούδας, δὲ, ἐγέννησεν, τὸν, Φάρες, καὶ, τὸν, ...
# 4      MATT 1.4  [Ἀρὰμ, δὲ, ἐγέννησεν, τὸν, Ἀμιναδάβ, Ἀμιναδὰβ,...
# 5      MATT 1.5  [Σαλμὼν, δὲ, ἐγέννησεν, τὸν, Βόες, ἐκ, τῆς, Ῥα...
# ...         ...                                                ...
# 8038  REV 22.17  [καὶ, τὸ, πνεῦμα, καὶ, ἡ, νύμφη, λέγουσιν, ἔρχ...
# 8039  REV 22.18  [μαρτυρῶ, ἐγὼ, παντὶ, τῷ, ἀκούοντι, τοὺς, λόγο...
# 8040  REV 22.19  [καὶ, ἐάν, τις, ἀφέλῃ, ἀπὸ, τῶν, λόγων, τοῦ, β...
# 8041  REV 22.20  [Λέγει, ὁ, μαρτυρῶν, ταῦτα, ναί, ἔρχομαι, ταχύ...
# 8042  REV 22.21       [Ἡ, χάρις, τοῦ, κυρίου, Ἰησοῦ, μετὰ, πάντων]
#
#                                                   lemma  \
# 1     [βίβλος, γένεσις, Ἰησοῦς, Χριστός, υἱός, Δαυίδ...
# 2     [Ἀβραάμ, γεννάω, ὁ, Ἰσαάκ, Ἰσαάκ, δέ, γεννάω, ...
# 3     [Ἰούδας, δέ, γεννάω, ὁ, Φάρες, καί, ὁ, Ζάρα, ἐ...
# 4     [Ἀράμ, δέ, γεννάω, ὁ, Ἀμιναδάβ, Ἀμιναδάβ, δέ, ...
# 5     [Σαλμών, δέ, γεννάω, ὁ, Βόες, ἐκ, ὁ, Ῥαχάβ, Βό...
# ...                                                 ...
# 8038  [καί, ὁ, πνεῦμα, καί, ὁ, νύμφη, λέγω, ἔρχομαι,...
# 8039  [μαρτυρέω, ἐγώ, πᾶς, ὁ, ἀκούω, ὁ, λόγος, ὁ, πρ...
# 8040  [καί, ἐάν, τὶς, ἀφαιρέω, ἀπό, ὁ, λόγος, ὁ, βιβ...
# 8041  [λέγω, ὁ, μαρτυρέω, οὗτος, ναί, ἔρχομαι, ταχύς...
# 8042           [ὁ, χάρις, ὁ, κύριος, Ἰησοῦς, μετά, πᾶς]
#
#                                                     pos
# 1                      [Nb, Nb, Ne, Ne, Nb, Ne, Nb, Ne]
# 2     [Ne, V-, S-, Ne, Ne, Df, V-, S-, Ne, Ne, Df, V...
# 3     [Ne, Df, V-, S-, Ne, C-, S-, Ne, R-, S-, Ne, N...
# 4     [Ne, Df, V-, S-, Ne, Ne, Df, V-, S-, Ne, Ne, D...
# 5     [Ne, Df, V-, S-, Ne, R-, S-, Ne, Ne, Df, V-, S...
# ...                                                 ...
# 8038  [C-, S-, Nb, C-, S-, Nb, V-, V-, C-, S-, V-, V...
# 8039  [V-, Pp, Px, S-, V-, S-, Nb, S-, Nb, S-, Nb, P...
# 8040  [C-, G-, Px, V-, R-, S-, Nb, S-, Nb, S-, Nb, P...
# 8041       [V-, S-, V-, Pd, I-, V-, A-, I-, V-, Nb, Ne]
# 8042                       [S-, Nb, S-, Nb, Ne, R-, Px]
#
# [8042 rows x 4 columns]

# %% [markdown]
# ## CSV export

# %%
# Save the NT dataframe to a CSV file
NT.to_csv('data/SBLGNT/NT.csv', index=False)
NT_sentence.to_csv('data/SBLGNT/NT_sentence.csv', index=False)
