# %%
"""
Created on July 2024
@author: Théotime de la Selle
"""

# import os, sys, time, random

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
import pickle
import nltk as nl
# from nltk.tokenize import word_tokenize,wordpunct_tokenize
# from nltk.stem import WordNetLemmatizer,PorterStemmer
# from nltk.corpus import words
# from nltk.corpus import stopwords
# from nltk.tokenize import RegexpTokenizer
# from scipy.signal import correlate

# %% [markdown]
# # Load and verify data

# %%
Evangiles = pickle.load(open("data/Evangiles.pkl", "rb"))
Mark = pickle.load(open("data/Mark.pkl", "rb"))
Matt = pickle.load(open("data/Matt.pkl", "rb"))
Luke = pickle.load(open("data/Luke.pkl", "rb"))
John = pickle.load(open("data/John.pkl", "rb"))

# Ev_verses = Evangiles.shape[0]
display(Evangiles.sample(5))

DM_Ev = pickle.load(open("distance_matrices/dist_mat_Ev.pkl", "rb"))
DM_Mc = pickle.load(open("distance_matrices/dist_mat_Mc.pkl", "rb"))
DM_Mt = pickle.load(open("distance_matrices/dist_mat_Mt.pkl", "rb"))
DM_Lc = pickle.load(open("distance_matrices/dist_mat_Lc.pkl", "rb"))
DM_Jn = pickle.load(open("distance_matrices/dist_mat_Jn.pkl", "rb"))
# Out:
#           verses                                               text  \
# 1709  Mark 15:36  δραμὼν δέ τις καὶ γεμίσας σπόγγον ὄξους περιθε...
# 1089   Mark 1:22  καὶ ἐξεπλήσσοντο ἐπὶ τῆι διδαχῆι αὐτοῦ ἦν γὰρ ...
# 2365  Luke 12:59  λέγω σοι οὐ μὴ ἐξέλθηις ἐκεῖθεν ἕως καὶ τὸ ἔσχ...
# 2892    John 1:3  πάντα δι αὐτοῦ ἐγένετο καὶ χωρὶς αὐτοῦ ἐγένετο...
# 66      Matt 4:2  καὶ νηστεύσας ἡμέρας τεσσεράκοντα καὶ νύκτας τ...
#
#                                                  tokens  \
# 1709  [δραμὼν, δέ, τις, καὶ, γεμίσας, σπόγγον, ὄξους...
# 1089  [καὶ, ἐξεπλήσσοντο, ἐπὶ, τῆι, διδαχῆι, αὐτοῦ, ...
# 2365  [λέγω, σοι, οὐ, μὴ, ἐξέλθηις, ἐκεῖθεν, ἕως, κα...
# 2892  [πάντα, δι, αὐτοῦ, ἐγένετο, καὶ, χωρὶς, αὐτοῦ,...
# 66    [καὶ, νηστεύσας, ἡμέρας, τεσσεράκοντα, καὶ, νύ...
#
#                                                 lemmata  \
# 1709  [τρέχω, δέ, τὶς, καί, γεμίζω, σπόγγος, ὄξος, π...
# 1089  [καί, ἐκπλήσσω, ἐπί, τῆι, διδαχῆι, αὐτός, εἰμί...
# 2365  [λέγω, σύ, οὐ, μή, ἐξέλθηις, ἐκεῖθεν, ἕως, καί...
# 2892  [πᾶς, δι, αὐτός, γίγνομαι, καί, χωρίς, αὐτός, ...
# 66    [καί, νηστεύω, ἡμέρα, τεσσεράκοντα, καί, νύξ, ...
#
#                                         tokens_filtered  \
# 1709  [δραμὼν, δέ, γεμίσας, σπόγγον, ὄξους, περιθεὶς...
# 1089  [ἐξεπλήσσοντο, τῆι, διδαχῆι, αὐτοῦ, ἦν, διδάσκ...
# 2365  [λέγω, σοι, ἐξέλθηις, ἐκεῖθεν, ἕως, ἔσχατον, λ...
# 2892  [πάντα, δι, αὐτοῦ, ἐγένετο, χωρὶς, αὐτοῦ, ἐγέν...
# 66    [νηστεύσας, ἡμέρας, τεσσεράκοντα, νύκτας, τεσσ...
#
#                                        lemmata_filtered  \
# 1709  [δραμὼν, γεμίζω, σπόγγος, ὄξος, περιτίθημι, κά...
# 1089  [ἐκπλήσσω, διδαχή, αὐτός, εἰμί, διδάσκω, αὐτός...
# 2365  [λέγω, ἐξέρχομαι, ἐκεῖθεν, ἔσχατος, λεπτός, ἀπ...
# 2892  [δι, αὐτός, γίγνομαι, χωρίς, αὐτός, γίγνομαι, ...
# 66    [νηστεύω, ἡμέρα, τεσσαράκοντα, νύξ, τεσσαράκον...
#
#                                                 bigrams  \
# 1709  [(δραμὼν, γεμίζω), (γεμίζω, σπόγγος), (σπόγγος...
# 1089  [(ἐκπλήσσω, διδαχή), (διδαχή, αὐτός), (αὐτός, ...
# 2365  [(λέγω, ἐξέρχομαι), (ἐξέρχομαι, ἐκεῖθεν), (ἐκε...
# 2892  [(δι, αὐτός), (αὐτός, γίγνομαι), (γίγνομαι, χω...
# 66    [(νηστεύω, ἡμέρα), (ἡμέρα, τεσσαράκοντα), (τεσ...
#
#                                                trigrams  \
# 1709  [(δραμὼν, γεμίζω, σπόγγος), (γεμίζω, σπόγγος, ...
# 1089  [(ἐκπλήσσω, διδαχή, αὐτός), (διδαχή, αὐτός, εἰ...
# 2365  [(λέγω, ἐξέρχομαι, ἐκεῖθεν), (ἐξέρχομαι, ἐκεῖθ...
# 2892  [(δι, αὐτός, γίγνομαι), (αὐτός, γίγνομαι, χωρί...
# 66    [(νηστεύω, ἡμέρα, τεσσαράκοντα), (ἡμέρα, τεσσα...
#
#                                           lemmata_tfidf  \
# 1709  [0.139008013826462, 0.10137393517390735, 0.159...
# 1089  [0.2330563204966287, 0.15955864428607744, 0.25...
# 2365  [0.17057023561450377, 0.2946241465109675, 0.42...
# 2892  [0.21574641900920663, 0.6875631185203863, 0.35...
# 66    [0.1994270834291227, 0.29326917297051397, 0.32...
#
#                                                     pos  \
# 1709  [verb, adverb, adjective, coordinating_conjunc...
# 1089  [coordinating_conjunction, verb, adposition, p...
# 2365  [verb, pronoun, adverb, adverb, verb, adverb, ...
# 2892  [adjective, pronoun, pronoun, verb, coordinati...
# 66    [coordinating_conjunction, verb, noun, numeral...
#
#                                                  morpho  \
# 1709  [[(habitual, imperfective, iterative, perfecti...
# 1089  [[], [(habitual, imperfective, iterative, perf...
# 2365  [[(admirative, conditional, desiderative, impe...
# 2892  [[(nominative, accusative, ergative, absolutiv...
# 66    [[], [(habitual, imperfective, iterative, perf...
#
#                                              vocabulary
# 1709  [αὐτός, γεμίζω, δραμὼν, εἶδον, κάλαμος, καθαιρ...
# 1089  [αὐτός, γραμματεύς, διδάσκω, διδαχή, εἰμί, ἐκπ...
# 2365  [λέγω, λεπτός, ἀποδίδωμι, ἐκεῖθεν, ἐξέρχομαι, ...
# 2892                 [αὐτός, γίγνομαι, δι, χωρίς, ἵημι]
# 66    [νηστεύω, νύξ, πεινάω, τεσσαράκοντα, ἡμέρα, ὕσ...

# %% [markdown]
# # Edit distance test on 2 verses

# %%
# Edit distance test on verses
id_verse_1 = "Mark 8:35"
id_verse_2 = "Luke 9:24"

id_verse_1 = "Matt 17:23"
id_verse_2 = "Mark 9:31"

def extract_verse(id_verse,df):   
    extracted_verse = df[df.verses == id_verse].reset_index(drop=True)
    display(extracted_verse)
    return extracted_verse

# Find the verses in dataframes
v_1 = extract_verse(id_verse_1,Evangiles)
v_2 = extract_verse(id_verse_2,Evangiles)

def compute_distance(v_1,v_2,method,info=False,transpos=False):
    str_v1 = v_1[method][0]
    len_v1 = len(str_v1)
    str_v2 = v_2[method][0]
    len_v2 = len(str_v2)
   
    # Compute edit distance
    # edit_dist = min((nl.edit_distance(str_v1,str_v2,transpositions=transpos)-abs(len_v1-len_v2)+1)/min(len_v1,len_v2),1.0)  # Normalized distance 1
    edit_dist = (nl.edit_distance(str_v1,str_v2,transpositions=transpos)-abs(len_v1-len_v2)+1)/(min(len_v1,len_v2)+1)  # Normalized distance 1
    # edit_dist = (nl.edit_distance(str_v1, str_v2,transpositions=transpos))/np.max([len_v1,len_v2])                # Normalized distance  2  
    # edit_dist = (nl.edit_distance(str_v1, str_v2)-abs(len_v1-len_v2))/min(len_v1,len_v2)                          # Raw distance (unity : words/characters)

    if info == True:
        print("\n-----",method,"-----\n")
        print(str_v1)
        print(str_v2)
        print(f"Edit distance between 2 verses :",edit_dist)
    return edit_dist

compute_distance(v_1,v_2,'text',True)
compute_distance(v_1,v_2,'tokens',True,True)
compute_distance(v_1,v_2,'lemmata',True,True)
compute_distance(v_1,v_2,'tokens_filtered',True,True)
compute_distance(v_1,v_2,'lemmata_filtered',True,True)
compute_distance(v_1,v_2,'pos',True,True)
compute_distance(v_1,v_2,'morpho',True,True)
compute_distance(v_1,v_2,'vocabulary',True,True)
# Out:
#        verses                                               text  \
# 0  Matt 17:23  καὶ ἀποκτενοῦσιν αὐτόν καὶ τῆι τρίτηι ἡμέραι ἐ...
#
#                                               tokens  \
# 0  [καὶ, ἀποκτενοῦσιν, αὐτόν, καὶ, τῆι, τρίτηι, ἡ...
#
#                                              lemmata  \
# 0  [καί, ἀποκτείνω, αὐτός, καί, τῆι, τρίτηι, ἡμέρ...
#
#                                      tokens_filtered  \
# 0  [ἀποκτενοῦσιν, αὐτόν, τῆι, τρίτηι, ἡμέραι, ἐγε...
#
#                                     lemmata_filtered  \
# 0  [ἀποκτείνω, αὐτός, τρίτος, ἡμέρα, ἐγείρω, λυπέ...
#
#                                              bigrams  \
# 0  [(ἀποκτείνω, αὐτός), (αὐτός, τρίτος), (τρίτος,...
#
#                                             trigrams  \
# 0  [(ἀποκτείνω, αὐτός, τρίτος), (αὐτός, τρίτος, ἡ...
#
#                                        lemmata_tfidf  \
# 0  [0.11647746683573529, 0.2832260035163413, 0.48...
#
#                                                  pos  \
# 0  [coordinating_conjunction, verb, pronoun, coor...
#
#                                               morpho  \
# 0  [[], [(admirative, conditional, desiderative, ...
#
#                                           vocabulary
# 0  [αὐτός, λυπέω, σφόδρα, τρίτος, ἀποκτείνω, ἐγεί...
#       verses                                               text  \
# 0  Mark 9:31  ἐδίδασκεν γὰρ τοὺς μαθητὰς αὐτοῦ καὶ ἔλεγεν αὐ...
#
#                                               tokens  \
# 0  [ἐδίδασκεν, γὰρ, τοὺς, μαθητὰς, αὐτοῦ, καὶ, ἔλ...
#
#                                              lemmata  \
# 0  [διδάσκω, γάρ, ὁ, μαθητής, αὐτός, καί, λέγω, α...
#
#                                      tokens_filtered  \
# 0  [ἐδίδασκεν, μαθητὰς, αὐτοῦ, ἔλεγεν, αὐτοῖς, υἱ...
#
#                                     lemmata_filtered  \
# 0  [διδάσκω, μαθητὰς, αὐτός, λέγω, αὐτός, υἱός, ἄ...
#
#                                              bigrams  \
# 0  [(διδάσκω, μαθητὰς), (μαθητὰς, αὐτός), (αὐτός,...
#
#                                             trigrams  \
# 0  [(διδάσκω, μαθητὰς, αὐτός), (μαθητὰς, αὐτός, λ...
#
#                                        lemmata_tfidf  \
# 0  [0.19500928960583144, 0.25457190256161816, 0.1...
#
#                                                  pos  \
# 0  [verb, adverb, determiner, noun, pronoun, coor...
#
#                                               morpho  \
# 0  [[(habitual, imperfective, iterative, perfecti...
#
#                                           vocabulary
# 0  [αὐτός, διδάσκω, λέγω, μαθητὰς, παραδίδωμι, τρ...
# ----- text -----
#
# καὶ ἀποκτενοῦσιν αὐτόν καὶ τῆι τρίτηι ἡμέραι ἐγερθήσεται καὶ ἐλυπήθησαν σφόδρα
# ἐδίδασκεν γὰρ τοὺς μαθητὰς αὐτοῦ καὶ ἔλεγεν αὐτοῖς ὅτι ὁ υἱὸς τοῦ ἀνθρώπου παραδίδοται εἰς χεῖρας ἀνθρώπων καὶ ἀποκτενοῦσιν αὐτόν καὶ ἀποκτανθεὶς μετὰ τρεῖς ἡμέρας ἀναστήσεται
# Edit distance between 2 verses : 0.5316455696202531
#
# ----- tokens -----
#
# ['καὶ', 'ἀποκτενοῦσιν', 'αὐτόν', 'καὶ', 'τῆι', 'τρίτηι', 'ἡμέραι', 'ἐγερθήσεται', 'καὶ', 'ἐλυπήθησαν', 'σφόδρα']
# ['ἐδίδασκεν', 'γὰρ', 'τοὺς', 'μαθητὰς', 'αὐτοῦ', 'καὶ', 'ἔλεγεν', 'αὐτοῖς', 'ὅτι', 'ὁ', 'υἱὸς', 'τοῦ', 'ἀνθρώπου', 'παραδίδοται', 'εἰς', 'χεῖρας', 'ἀνθρώπων', 'καὶ', 'ἀποκτενοῦσιν', 'αὐτόν', 'καὶ', 'ἀποκτανθεὶς', 'μετὰ', 'τρεῖς', 'ἡμέρας', 'ἀναστήσεται']
# Edit distance between 2 verses : 0.8333333333333334
#
# ----- lemmata -----
#
# ['καί', 'ἀποκτείνω', 'αὐτός', 'καί', 'τῆι', 'τρίτηι', 'ἡμέρα', 'ἐγείρω', 'καί', 'λυπέω', 'σφόδρα']
# ['διδάσκω', 'γάρ', 'ὁ', 'μαθητής', 'αὐτός', 'καί', 'λέγω', 'αὐτός', 'ὅτι', 'ὁ', 'υἱός', 'ὁ', 'ἄνθρωπος', 'παραδίδωμι', 'εἰς', 'χείρ', 'ἄνθρωπος', 'καί', 'ἀποκτείνω', 'αὐτός', 'καί', 'ἀποκτείνω', 'μετά', 'τρεῖς', 'ἡμέρα', 'ἀνίστημι']
# Edit distance between 2 verses : 0.75
#
# ----- tokens_filtered -----
#
# ['ἀποκτενοῦσιν', 'αὐτόν', 'τῆι', 'τρίτηι', 'ἡμέραι', 'ἐγερθήσεται', 'ἐλυπήθησαν', 'σφόδρα']
# ['ἐδίδασκεν', 'μαθητὰς', 'αὐτοῦ', 'ἔλεγεν', 'αὐτοῖς', 'υἱὸς', 'ἀνθρώπου', 'παραδίδοται', 'χεῖρας', 'ἀνθρώπων', 'ἀποκτενοῦσιν', 'αὐτόν', 'ἀποκτανθεὶς', 'τρεῖς', 'ἡμέρας', 'ἀναστήσεται']
# Edit distance between 2 verses : 1.0
#
# ----- lemmata_filtered -----
#
# ['ἀποκτείνω', 'αὐτός', 'τρίτος', 'ἡμέρα', 'ἐγείρω', 'λυπέω', 'σφόδρα']
# ['διδάσκω', 'μαθητὰς', 'αὐτός', 'λέγω', 'αὐτός', 'υἱός', 'ἄνθρωπος', 'παραδίδωμι', 'χείρ', 'ἄνθρωπος', 'ἀποκτείνω', 'αὐτός', 'ἀποκτανθεὶς', 'τρεῖς', 'ἡμέρα', 'ἀνίστημι']
# Edit distance between 2 verses : 0.875
#
# ----- pos -----
#
# ['coordinating_conjunction', 'verb', 'pronoun', 'coordinating_conjunction', 'determiner', 'noun', 'noun', 'verb', 'coordinating_conjunction', 'verb', 'adverb']
# ['verb', 'adverb', 'determiner', 'noun', 'pronoun', 'coordinating_conjunction', 'verb', 'pronoun', 'subordinating_conjunction', 'determiner', 'noun', 'determiner', 'noun', 'verb', 'adposition', 'noun', 'noun', 'coordinating_conjunction', 'verb', 'pronoun', 'coordinating_conjunction', 'verb', 'adposition', 'numeral', 'noun', 'verb']
# Edit distance between 2 verses : 0.25
#
# ----- morpho -----
#
# [{}, {Mood: [indicative], Number: [plural], Person: [third], Tense: [future], VerbForm: [finite], Voice: [active]}, {Case: [accusative], Gender: [masculine], Number: [singular], Person: [third], PronominalType: [personal]}, {}, {Case: [genitive], Definiteness: [definite], Gender: [feminine], Number: [plural], PronominalType: [demonstrative]}, {Case: [nominative], Gender: [feminine], Number: [plural]}, {Case: [nominative], Gender: [feminine], Number: [plural]}, {Mood: [indicative], Number: [singular], Person: [third], Tense: [future], VerbForm: [finite], Voice: [passive]}, {}, {Aspect: [perfective], Mood: [indicative], Number: [plural], Person: [third], Tense: [past], VerbForm: [finite], Voice: [passive]}, {}]
# [{Aspect: [imperfective], Mood: [indicative], Number: [singular], Person: [third], Tense: [past], VerbForm: [finite], Voice: [active]}, {}, {Case: [accusative], Definiteness: [definite], Gender: [masculine], Number: [plural], PronominalType: [demonstrative]}, {Case: [accusative], Gender: [masculine], Number: [plural]}, {Case: [genitive], Gender: [masculine], Number: [singular], Person: [third], PronominalType: [personal]}, {}, {Aspect: [imperfective], Mood: [indicative], Number: [singular], Person: [third], Tense: [past], VerbForm: [finite], Voice: [active]}, {Case: [dative], Gender: [masculine], Number: [plural], Person: [third], PronominalType: [personal]}, {}, {Case: [nominative], Definiteness: [definite], Gender: [masculine], Number: [singular], PronominalType: [demonstrative]}, {Case: [nominative], Gender: [masculine], Number: [singular]}, {Case: [genitive], Definiteness: [definite], Gender: [masculine], Number: [singular], PronominalType: [demonstrative]}, {Case: [genitive], Gender: [masculine], Number: [singular]}, {Mood: [indicative], Number: [singular], Person: [third], Tense: [present], VerbForm: [finite], Voice: [passive]}, {}, {Case: [accusative], Gender: [feminine], Number: [plural]}, {Case: [genitive], Gender: [masculine], Number: [plural]}, {}, {Mood: [indicative], Number: [plural], Person: [third], Tense: [future], VerbForm: [finite], Voice: [active]}, {Case: [accusative], Gender: [masculine], Number: [singular], Person: [third], PronominalType: [personal]}, {}, {Aspect: [perfective], Case: [nominative], Gender: [masculine], Number: [singular], Tense: [past], VerbForm: [participle], Voice: [passive]}, {}, {Case: [accusative], Gender: [feminine], Number: [plural]}, {Case: [accusative], Gender: [feminine], Number: [plural]}, {Mood: [indicative], Number: [singular], Person: [third], Tense: [future], VerbForm: [finite], Voice: [middle]}]
# Edit distance between 2 verses : 1.0
#
# ----- vocabulary -----
#
# ['αὐτός', 'λυπέω', 'σφόδρα', 'τρίτος', 'ἀποκτείνω', 'ἐγείρω', 'ἡμέρα']
# ['αὐτός', 'διδάσκω', 'λέγω', 'μαθητὰς', 'παραδίδωμι', 'τρεῖς', 'υἱός', 'χείρ', 'ἀνίστημι', 'ἀποκτανθεὶς', 'ἀποκτείνω', 'ἄνθρωπος', 'ἡμέρα']
# Edit distance between 2 verses : 0.625
# 0.625

# %% [markdown]
# # Set of verses comparison

# %%
def comparison(v_1,len_1,v_2,len_2,df,DM):

    # Find verses indexes
    v_1_id = df.loc[df["verses"]==v_1].index[0]
    v_2_id = df.loc[df["verses"]==v_2].index[0]
    
    # Building grid matrix for extraction
    grid = np.indices((len_1,len_2))
    row = [g+v_1_id for g in grid[0]]
    col = [g+v_2_id for g in grid[1]]

    print(DM[2][v_1_id,v_2_id])
    
    # Extract reduced similarity matrices
    DM = [np.triu(M, k=1)+np.triu(M, k=1).T for M in DM]
    DM_ext = [M[row,col] for M in DM]

    if len_1<len_2: DM_ext = [M.T for M in DM_ext]   
    
    # Compute metrics through mean of maximum correspondance couples
    txt_metrics = []
    id_association = []
    for M in DM_ext:
        mini = []
        idx = []
        for i in range(max(len_1,len_2)):
            mini.append(np.min(M))
            idx.append(np.where(M==mini[i]))
            # M = np.delete(M,idx[i][0][0],0)     # Delete the row of the minimum
            M[idx[i]] = 1.0   # exclude minimum value at each step
                          
        txt_metrics.append(mini)
        id_association.append(idx)

    txt_metrics_mean = [np.mean(values) for values in txt_metrics]
    
    return txt_metrics_mean

# %%
import matplotlib.pyplot as plt
import numpy as np

from matplotlib.patches import Circle, RegularPolygon
from matplotlib.path import Path
from matplotlib.projections import register_projection
from matplotlib.projections.polar import PolarAxes
from matplotlib.spines import Spine
from matplotlib.transforms import Affine2D


def radar_factory(num_vars, frame='circle'):
    """
    Create a radar chart with `num_vars` Axes.

    This function creates a RadarAxes projection and registers it.

    Parameters
    ----------
    num_vars : int
        Number of variables for radar chart.
    frame : {'circle', 'polygon'}
        Shape of frame surrounding Axes.

    """
    # calculate evenly-spaced axis angles
    theta = np.linspace(0, 2*np.pi, num_vars, endpoint=False)

    class RadarTransform(PolarAxes.PolarTransform):

        def transform_path_non_affine(self, path):
            # Paths with non-unit interpolation steps correspond to gridlines,
            # in which case we force interpolation (to defeat PolarTransform's
            # autoconversion to circular arcs).
            if path._interpolation_steps > 1:
                path = path.interpolated(num_vars)
            return Path(self.transform(path.vertices), path.codes)

    class RadarAxes(PolarAxes):

        name = 'radar'
        PolarTransform = RadarTransform

        def __init__(self, *args, **kwargs):
            super().__init__(*args, **kwargs)
            # rotate plot such that the first axis is at the top
            self.set_theta_zero_location('N')

        def fill(self, *args, closed=True, **kwargs):
            """Override fill so that line is closed by default"""
            return super().fill(closed=closed, *args, **kwargs)

        def plot(self, *args, **kwargs):
            """Override plot so that line is closed by default"""
            lines = super().plot(*args, **kwargs)
            for line in lines:
                self._close_line(line)

        def _close_line(self, line):
            x, y = line.get_data()
            # FIXME: markers at x[0], y[0] get doubled-up
            if x[0] != x[-1]:
                x = np.append(x, x[0])
                y = np.append(y, y[0])
                line.set_data(x, y)

        def set_varlabels(self, labels):
            self.set_thetagrids(np.degrees(theta), labels)

        def _gen_axes_patch(self):
            # The Axes patch must be centered at (0.5, 0.5) and of radius 0.5
            # in axes coordinates.
            if frame == 'circle':
                return Circle((0.5, 0.5), 0.5)
            elif frame == 'polygon':
                return RegularPolygon((0.5, 0.5), num_vars,
                                      radius=.5, edgecolor="k")
            else:
                raise ValueError("Unknown value for 'frame': %s" % frame)

        def _gen_axes_spines(self):
            if frame == 'circle':
                return super()._gen_axes_spines()
            elif frame == 'polygon':
                # spine_type must be 'left'/'right'/'top'/'bottom'/'circle'.
                spine = Spine(axes=self,
                              spine_type='circle',
                              path=Path.unit_regular_polygon(num_vars))
                # unit_regular_polygon gives a polygon of radius 1 centered at
                # (0, 0) but we want a polygon of radius 0.5 centered at (0.5,
                # 0.5) in axes coordinates.
                spine.set_transform(Affine2D().scale(.5).translate(.5, .5)
                                    + self.transAxes)
                return {'polar': spine}
            else:
                raise ValueError("Unknown value for 'frame': %s" % frame)

    register_projection(RadarAxes)
    return theta

# %% [markdown]
# ### Verses selection and radar plot

# %%
set_verses_len_1 = 3
verse_1 = "Matt 14:14"
verse_2 = "Mark 6:34"
set_verses_len_2 = 4

# verse_1 = "John 1:1"
# # verse_1 = "Luke 9:22"
# set_verses_len_1 = 1
# verse_2 = "Luke 8:11"
# verse_2 = "John 1:2"
# set_verses_len_2 = 1

# %%
theta = radar_factory(5, frame='polygon')

metrics_values = comparison(verse_1,set_verses_len_1,verse_2,set_verses_len_2,Evangiles,DM_Ev)
print(metrics_values)
data = [
    ['Tokens','Lemmata','Lemmata filtered','Vocabulary', 'Parts-of-speech'],
    ('Mean metrics of '+verse_1+' + '+str(set_verses_len_1-1)+' and '+verse_2+' + '+str(set_verses_len_2-1), metrics_values[0:5])]

# spoke_labels = data.pop(0)

fig, axs = plt.subplots(figsize=(7, 7), nrows=1, ncols=1,
                        subplot_kw=dict(projection='radar'))
fig.subplots_adjust(wspace=0.25, hspace=0.20, top=0.85, bottom=0.05)

colors = ['b']
title,case_data = data[1]
axs.set_rgrids([0,0.05,0.1,0.15,0.2,0.25,0.3,0.35, 0.4,0.5, 0.6,0.7, 0.8,0.9])
axs.set_title(title, weight='bold', size='medium', position=(0.5, 1.1),
             horizontalalignment='center', verticalalignment='center')
axs.plot(theta, case_data,color='b')
axs.fill(theta, case_data, facecolor='r', alpha=0.25, label='_nolegend_')
axs.set_varlabels(data[0])

# add legend relative to top-left plot
# labels = ('Factor 1', 'Factor 2', 'Factor 3', 'Factor 4', 'Factor 5')
# legend = axs[0].legend(labels, loc=(0.9, .95),
#                           labelspacing=0.1, fontsize='small')

# fig.text(0.5, 0.965, '5-Factor Solution Profiles Across Four Scenarios',
#          horizontalalignment='center', color='black', weight='bold',
#          size='large')

plt.show()
# Out:
# 0.2222222222222222
# [0.6145604395604396, 0.5153846153846154, 0.4662698412698413, 0.38920454545454547, 0.37225274725274726]
